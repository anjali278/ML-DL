# %%
import pandas

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
cd drive/MyDrive/
# Out:
# /content/drive/MyDrive

# %%
dataset  =  pandas.read_csv('pima-indians-diabetes.data.csv' , header=None)

# %%
dataset.head(5)
# Out:
#    0    1   2   3    4     5      6   7  8
# 0  6  148  72  35    0  33.6  0.627  50  1
# 1  1   85  66  29    0  26.6  0.351  31  0
# 2  8  183  64   0    0  23.3  0.672  32  1
# 3  1   89  66  23   94  28.1  0.167  21  0
# 4  0  137  40  35  168  43.1  2.288  33  1

# %%
y = dataset[8]

# %%
X = dataset[[0,1,2,3,4,5,6,7]]

# %%
X.shape
# Out:
# (768, 8)

# %%
from keras.models  import Sequential

# %%
model = Sequential()

# %%
from keras.layers import Dense

# %%
model.add( Dense(units=10,  
                 kernel_initializer="zeros", 
                 bias_initializer="zeros",
                 input_dim=8,
                 activation='relu'
                 
                )  )

# %%
model.add( Dense(units=8,  
                 kernel_initializer="zeros", 
                 bias_initializer="zeros",
            
                 activation='relu'
                 
                )  )

# %%
model.add(Dense(  
        units=6,
        activation='relu',
        kernel_initializer="zeros", 
        bias_initializer="zeros",
        
    ))

# %%
model.add(Dense( units=1, 
                activation='sigmoid',
                kernel_initializer="zeros", 
                bias_initializer="zeros",
               
               ))

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 10)                90
# _________________________________________________________________
# dense_1 (Dense)              (None, 8)                 88
# _________________________________________________________________
# dense_2 (Dense)              (None, 6)                 54
# _________________________________________________________________
# dense_3 (Dense)              (None, 1)                 7
# _________________________________________________________________
# dense_4 (Dense)              (None, 20)                40
# _________________________________________________________________
# dense_5 (Dense)              (None, 16)                336
# _________________________________________________________________
# dense_6 (Dense)              (None, 14)                238
# _________________________________________________________________
# dense_7 (Dense)              (None, 1)                 15
# _________________________________________________________________
# dense_8 (Dense)              (None, 50)                100
# _________________________________________________________________
# dense_9 (Dense)              (None, 30)                1530
# _________________________________________________________________
# dense_10 (Dense)             (None, 15)                465
# _________________________________________________________________
# dense_11 (Dense)             (None, 1)                 16
# _________________________________________________________________
# dense_12 (Dense)             (None, 8)                 16
# _________________________________________________________________
# dense_13 (Dense)             (None, 10)                90
# _________________________________________________________________
# dense_14 (Dense)             (None, 8)                 88
# _________________________________________________________________
# dense_15 (Dense)             (None, 6)                 54
# _________________________________________________________________
# dense_16 (Dense)             (None, 1)                 7
# =================================================================
# Total params: 3,234
# Trainable params: 3,234
# Non-trainable params: 0
# _________________________________________________________________

# %%
from keras.optimizers  import Adam

# %%
model.compile(optimizer=Adam() ,  loss="binary_crossentropy", metrics=["accuracy"])

# %%
model.fit(X,y, epochs=100)
# Out:
# Epoch 1/100
# 24/24 [==============================] - 2s 2ms/step - loss: 0.6924 - accuracy: 0.6622
# Epoch 2/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.6895 - accuracy: 0.6463
# Epoch 3/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.6860 - accuracy: 0.6613
# Epoch 4/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.6830 - accuracy: 0.6621
# Epoch 5/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.6829 - accuracy: 0.6310
# Epoch 6/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.6802 - accuracy: 0.6368
# Epoch 7/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.6777 - accuracy: 0.6406
# Epoch 8/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.6686 - accuracy: 0.6930
# Epoch 9/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.6727 - accuracy: 0.6487
# Epoch 10/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.6673 - accuracy: 0.6692
# Epoch 11/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.6694 - accuracy: 0.6468
# Epoch 12/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.6690 - accuracy: 0.6417
# Epoch 13/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.6684 - accuracy: 0.6380
# Epoch 14/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.6640 - accuracy: 0.6511
# Epoch 15/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.6672 - accuracy: 0.6330
# Epoch 16/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.6568 - accuracy: 0.6683
# Epoch 17/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.6585 - accuracy: 0.6569
# Epoch 18/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.6565 - accuracy: 0.6597
# Epoch 19/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.6497 - accuracy: 0.6777
# Epoch 20/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.6657 - accuracy: 0.6246
# Epoch 21/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.6509 - accuracy: 0.6672
# Epoch 22/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.6495 - accuracy: 0.6682
# Epoch 23/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.6542 - accuracy: 0.6525
# Epoch 24/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.6475 - accuracy: 0.6688
# Epoch 25/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.6551 - accuracy: 0.6467
# Epoch 26/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.6580 - accuracy: 0.6381
# Epoch 27/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.6459 - accuracy: 0.6670
# Epoch 28/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.6552 - accuracy: 0.6428
# Epoch 29/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.6544 - accuracy: 0.6437
# Epoch 30/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.6509 - accuracy: 0.6512
# Epoch 31/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.6375 - accuracy: 0.6806
# Epoch 32/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.6614 - accuracy: 0.6264
# Epoch 33/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.6470 - accuracy: 0.6575
# Epoch 34/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.6501 - accuracy: 0.6501
# Epoch 35/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.6404 - accuracy: 0.6700
# Epoch 36/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.6616 - accuracy: 0.6250
# Epoch 37/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.6459 - accuracy: 0.6574
# Epoch 38/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.6499 - accuracy: 0.6487
# Epoch 39/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.6523 - accuracy: 0.6436
# Epoch 40/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.6512 - accuracy: 0.6455
# Epoch 41/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.6489 - accuracy: 0.6498
# Epoch 42/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.6559 - accuracy: 0.6358
# Epoch 43/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.6613 - accuracy: 0.6256
# Epoch 44/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.6397 - accuracy: 0.6666
# Epoch 45/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.6491 - accuracy: 0.6484
# Epoch 46/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.6423 - accuracy: 0.6610
# Epoch 47/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.6457 - accuracy: 0.6545
# Epoch 48/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.6534 - accuracy: 0.6401
# Epoch 49/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.6596 - accuracy: 0.6288
# Epoch 50/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.6485 - accuracy: 0.6490
# Epoch 51/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.6397 - accuracy: 0.6647
# Epoch 52/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.6343 - accuracy: 0.6740
# Epoch 53/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.6510 - accuracy: 0.6444
# Epoch 54/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.6452 - accuracy: 0.6544
# Epoch 55/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.6476 - accuracy: 0.6502
# Epoch 56/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.6353 - accuracy: 0.6716
# Epoch 57/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.6482 - accuracy: 0.6491
# Epoch 58/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.6388 - accuracy: 0.6653
# Epoch 59/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.6501 - accuracy: 0.6458
# Epoch 60/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.6534 - accuracy: 0.6400
# Epoch 61/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.6553 - accuracy: 0.6367
# Epoch 62/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.6499 - accuracy: 0.6461
# Epoch 63/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.6278 - accuracy: 0.6835
# Epoch 64/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.6502 - accuracy: 0.6456
# Epoch 65/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.6522 - accuracy: 0.6421
# Epoch 66/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.6528 - accuracy: 0.6412
# Epoch 67/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.6364 - accuracy: 0.6686
# Epoch 68/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.6428 - accuracy: 0.6578
# Epoch 69/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.6542 - accuracy: 0.6388
# Epoch 70/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.6378 - accuracy: 0.6662
# Epoch 71/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.6546 - accuracy: 0.6382
# Epoch 72/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.6611 - accuracy: 0.6274
# Epoch 73/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.6372 - accuracy: 0.6670
# Epoch 74/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.6625 - accuracy: 0.6252
# Epoch 75/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.6338 - accuracy: 0.6726
# Epoch 76/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.6290 - accuracy: 0.6803
# Epoch 77/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.6479 - accuracy: 0.6493
# Epoch 78/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.6359 - accuracy: 0.6690
# Epoch 79/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.6399 - accuracy: 0.6624
# Epoch 80/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.6500 - accuracy: 0.6459
# Epoch 81/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.6425 - accuracy: 0.6581
# Epoch 82/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.6543 - accuracy: 0.6388
# Epoch 83/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.6540 - accuracy: 0.6392
# Epoch 84/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.6404 - accuracy: 0.6615
# Epoch 85/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.6533 - accuracy: 0.6404
# Epoch 86/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.6492 - accuracy: 0.6471
# Epoch 87/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.6428 - accuracy: 0.6576
# Epoch 88/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.6515 - accuracy: 0.6434
# Epoch 89/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.6308 - accuracy: 0.6771
# Epoch 90/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.6444 - accuracy: 0.6550
# Epoch 91/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.6477 - accuracy: 0.6496
# Epoch 92/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.6534 - accuracy: 0.6404
# Epoch 93/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.6513 - accuracy: 0.6437
# Epoch 94/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.6373 - accuracy: 0.6664
# Epoch 95/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.6241 - accuracy: 0.6876
# Epoch 96/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.6540 - accuracy: 0.6394
# Epoch 97/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.6434 - accuracy: 0.6566
# Epoch 98/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.6499 - accuracy: 0.6460
# Epoch 99/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.6386 - accuracy: 0.6643
# Epoch 100/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.6567 - accuracy: 0.6350
